# %% [markdown]
# <a href="https://colab.research.google.com/github/manishmeshram51/pima_indians_diabetes/blob/master/pima_indians_diabetes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link of the project
#
# https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/

# %%
# my first project 
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd

# %% [markdown]
# Data :
#
# The variables can be summarized as follows:
#
# Input Variables (X):
#
# 1.   Number of times pregnant
# 2.   Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#
# 1.   Diastolic blood pressure (mm Hg)
# 2.   Triceps skin fold thickness (mm)
#
# 1.   2-Hour serum insulin (mu U/ml)
# 2.   Body mass index (weight in kg/(height in m)^2)
#
# 1.   Diabetes pedigree function
# 2.   Age (years)
#
# Output Variables (y):
#
#
# 1.   Class variable (0 or 1)

# %%
#data 
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv'

dataset = np.loadtxt(url,delimiter = ',')

X = dataset[:,0:8]
y = dataset[:,8]

# %%
# define the keras model

model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(12,input_dim = 8, activation='relu'),
  tf.keras.layers.Dense(8, activation='relu'),
  tf.keras.layers.Dense(8, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
model.fit(X, y, epochs=500, batch_size=10)
# Out:
# Train on 768 samples
# Epoch 1/500
# 768/768 [==============================] - 0s 249us/sample - loss: 0.7617 - acc: 0.6302
# Epoch 2/500
# 768/768 [==============================] - 0s 126us/sample - loss: 0.6880 - acc: 0.6536
# Epoch 3/500
# 768/768 [==============================] - 0s 125us/sample - loss: 0.6786 - acc: 0.6484
# Epoch 4/500
# 768/768 [==============================] - 0s 132us/sample - loss: 0.6478 - acc: 0.6615
# Epoch 5/500
# 768/768 [==============================] - 0s 129us/sample - loss: 0.6623 - acc: 0.6654
# Epoch 6/500
# 768/768 [==============================] - 0s 137us/sample - loss: 0.6405 - acc: 0.6654
# Epoch 7/500
# 768/768 [==============================] - 0s 155us/sample - loss: 0.6086 - acc: 0.6745
# Epoch 8/500
# 768/768 [==============================] - 0s 134us/sample - loss: 0.6317 - acc: 0.6667
# Epoch 9/500
# 768/768 [==============================] - 0s 129us/sample - loss: 0.6271 - acc: 0.6667
# Epoch 10/500
# ...

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 768/768 [==============================] - 0s 96us/sample - loss: 0.3912 - acc: 0.8112
# Accuracy: 81.12

# %%
# make class predictions with the model
predictions = model.predict_classes(X)
# summarize the first 5 cases
for i in range(5):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
# [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)
